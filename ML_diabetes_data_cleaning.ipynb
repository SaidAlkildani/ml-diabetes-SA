# %% [markdown]
# # Cleaning Data

# %%
import pandas as pd
import numpy as np
import missingno as mno
import seaborn as sns

# %%
# loading data
df_diabetes = pd.read_csv("/Users/saidalkildani/Desktop/DS_AI/Projects/ML_diabetes_SA/ml-diabetes-SA/ML_diabetes.csv")

# %%
df_diabetes
# Out:
#       id  Age  pregnancies   bmi  insulin  glucose  bloodpressure  patientid
# 0      1   50            6  33.6        0      148             72          1  \
# 1      2   31            1  26.6        0       85             66          2
# 2      3   32            8  23.3        0      183             64          3
# 3      4   21            1  28.1       94       89             66          4
# 4      5   33            0  43.1      168      137             40          5
# ..   ...  ...          ...   ...      ...      ...            ...        ...
# 763  764   63           10  32.9      180      101             76        764
# 764  765   27            2  36.8        0      122             70        765
# 765  766   30            5  26.2      112      121             72        766
# 766  767   47            1  30.1        0      126             60        767
# 767  768   23            1  30.4        0       93             70        768
#
# ...

# %% [markdown]
# ## Columns and Data Types

# %%
# Check data types
df_diabetes.dtypes
## no need for conversions
# Out:
# id                            int64
# Age                           int64
# pregnancies                   int64
# bmi                         float64
# insulin                       int64
# glucose                       int64
# bloodpressure                 int64
# patientid                     int64
# measurement_date             object
# skinthickness                 int64
# diabetespedigreefunction    float64
# outcome                       int64
# dtype: object

# %%
## Drop unnecessary columns
df_diabetes.drop(columns=['patientid'], inplace=True)
df_diabetes.drop(columns=['measurement_date'], inplace=True)

# %% [markdown]
# ## Missing values

# %%
# Check for missing values
df_diabetes.isnull().sum()
## no missing values
# Out:
# id                          0
# Age                         0
# pregnancies                 0
# bmi                         0
# insulin                     0
# glucose                     0
# bloodpressure               0
# skinthickness               0
# diabetespedigreefunction    0
# outcome                     0
# dtype: int64

# %%
# Check for zero values in features
df_diabetes.describe()
# Zero values in insulin, skin thickness, glucose, bmi, and blood pressure are not acceptable measurements. 
# Replace the zeros with mean values after train-test splitting the data
# Out:
#                id         Age  pregnancies         bmi     insulin
# count  768.000000  768.000000   768.000000  768.000000  768.000000  \
# mean   384.500000   33.240885     3.845052   31.992578   79.799479
# std    221.846794   11.760232     3.369578    7.884160  115.244002
# min      1.000000   21.000000     0.000000    0.000000    0.000000
# 25%    192.750000   24.000000     1.000000   27.300000    0.000000
# 50%    384.500000   29.000000     3.000000   32.000000   30.500000
# 75%    576.250000   41.000000     6.000000   36.600000  127.250000
# max    768.000000   81.000000    17.000000   67.100000  846.000000
#
#           glucose  bloodpressure  skinthickness  diabetespedigreefunction
# count  768.000000     768.000000     768.000000                768.000000  \
# mean   120.894531      69.105469      20.536458                  0.471876
# std     31.972618      19.355807      15.952218                  0.331329
# ...

# %% [markdown]
# ## Checking for Duplicates

# %%
# There are no duplicates in the data
df_diabetes[df_diabetes.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Age, pregnancies, bmi, insulin, glucose, bloodpressure, skinthickness, diabetespedigreefunction, outcome]
# Index: []

# %% [markdown]
# ## Saving the Clean Data

# %%
# Export the clean data to a csv-file
df_diabetes.to_csv('ML_diabetes_clean.csv',index=False)

# %%
df_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        768 non-null    int64
#  1   Age                       768 non-null    int64
#  2   pregnancies               768 non-null    int64
#  3   bmi                       768 non-null    float64
#  4   insulin                   768 non-null    int64
#  5   glucose                   768 non-null    int64
#  6   bloodpressure             768 non-null    int64
#  7   skinthickness             768 non-null    int64
#  8   diabetespedigreefunction  768 non-null    float64
#  9   outcome                   768 non-null    int64
# dtypes: float64(2), int64(8)
# memory usage: 60.1 KB
